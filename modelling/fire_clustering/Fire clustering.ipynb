# %%
import pandas as pd

import seaborn as sns
# %matplotlib inline

from sklearn.cluster import MeanShift, KMeans, AgglomerativeClustering
from sklearn.neighbors import NearestNeighbors

# %%
fires = pd.read_csv("./oct/fire_nrt_V1_26765.csv")

FEATURE_NAMES = [
    "latitude",
    "longitude"
]

X = fires[FEATURE_NAMES]

# %%
mean_shift = MeanShift(n_jobs=-1)

# %%
mean_shift.fit(X)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-e6a4e942decb> in <module>
# ----> 1 mean_shift.fit(X)
#
# ~/anaconda2/envs/NASA/lib/python3.7/site-packages/sklearn/cluster/mean_shift_.py in fit(self, X, y)
#     419                        min_bin_freq=self.min_bin_freq,
#     420                        bin_seeding=self.bin_seeding,
# --> 421                        cluster_all=self.cluster_all, n_jobs=self.n_jobs)
#     422         return self
#     423
#
# ~/anaconda2/envs/NASA/lib/python3.7/site-packages/sklearn/cluster/mean_shift_.py in mean_shift(X, bandwidth, seeds, bin_seeding, min_bin_freq, cluster_all, max_iter, n_jobs)
#     199     all_res = Parallel(n_jobs=n_jobs)(
#     200         delayed(_mean_shift_single_seed)
# --> 201         (seed, X, nbrs, max_iter) for seed in seeds)
#     202     # copy results in a dictionary
# ...

# %%
mean_shift.cluster_centers_
# Out:
# array([[43.50171139, 23.95054198],
#        [43.75388226, 27.55278949],
#        [43.67266079, 26.20812353]])

# %%
sns.scatterplot(X["latitude"], X["longitude"], hue=mean_shift.labels_)

# %%
k_means = KMeans(n_clusters=4, init="random", n_init=1000, max_iter=10000, n_jobs=-1)

# %%
k_means.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=10000000,
#     n_clusters=4, n_init=10000, n_jobs=-1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
sns.scatterplot(X["latitude"], X["longitude"], hue=k_means.labels_)

# %%
agg_cluster = AgglomerativeClustering(n_clusters=2, linkage='single')

# %%
agg_cluster.fit(X)
# Out:
# AgglomerativeClustering(affinity='euclidean', compute_full_tree='auto',
#             connectivity=None, linkage='single', memory=None, n_clusters=2,
#             pooling_func='deprecated')

# %%
sns.scatterplot(X["latitude"], X["longitude"], hue=agg_cluster.labels_)
